# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import csv
from tabulate import tabulate
from fuzzywuzzy import fuzz, process

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/soleadify-dataset/google dataset.csv
# /kaggle/input/soleadify-dataset/website dataset.csv
# /kaggle/input/soleadify-dataset/facebook dataset.csv

# %% [markdown]
# **<font size="6"> DATASETS MERGING </font>**
# </br>
# </br>
# </br>
# We have three datasets containing information about the same companies, extracted from three different places:
# * Facebook
# * Google
# * Companies' websites
#
# The final goal of this project is to create a fourth dataset which must be obtained by joining the other three datasets, in order to get a high accuracy (as high as possible) for the following common columns: Category, Address(Country, Region, City), Phone, Company names.

# %% [markdown]
# First things first, I will clean the three datasets.

# %% [markdown]
# **<font size="4"> WEBSITE DATASET:</font>**

# %%
web_ds = pd.read_csv('/kaggle/input/soleadify-dataset/website dataset.csv', error_bad_lines=False, low_memory=False)
web_ds.head(15)
print('no. of rows: ',web_ds.shape[0])
print('no. of columns: ', web_ds.shape[1])
web_ds.head(15)
# Out:
# no. of rows:  71917
# no. of columns:  17
#               root_domain domain_suffix language  \
# 0        converterman.com           NaN      NaN
# 1     clothesencounter.ca            ca       en
# 2          investa.com.au        com.au       en
# 3       timminsgarage.com           com       en
# 4            destinate.ca            ca       en
# 5             ironcrow.ca            ca       en
# 6       springboarddm.com           com       en
# 7    stoneandtilesrus.com           com       en
# 8            mdaccpap.com           com       en
# 9             micacchi.ca            ca       en
# 10       skicollision.com           com       en
# 11  libertelightdance.com           com       en
# 12   rhein-kreis-neuss.de            de       de
# 13       unitysodfarm.com           com       en
# 14            cdncoin.com           com       en
#
#                                     legal_name      main_city main_country  \
# 0                                          NaN            NaN          NaN
# 1                                          NaN       cardigan       canada
# 2   Investa Wholesale Funds Management Limited       brisbane    australia
# 3                          Timmins Garage Inc.        timmins       canada
# 4                         Destinate Group Ltd.            NaN       Canada
# 5                                          NaN        calgary       canada
# 6                          The Hershey Company    mississauga       canada
# 7                                          NaN       brampton       canada
# 8                                MDAC CPAP INC    thunder bay       canada
# 9                                          NaN        toronto       canada
# 10                                         NaN       winnipeg       canada
# 11   LIBERTE LIGHT DANCE, SCHOOL OF DANCE INC.      moose jaw       canada
# 12                                         NaN          neuss      germany
# 13                         Unity Sod Farm Ltd.            NaN          NaN
# 14                        HUDSON'S BAY COMPANY  richmond hill       canada
#
#                main_region        phone                    site_name  tld  \
# 0                      NaN          NaN                          NaN  NaN
# 1     prince edward island  13066937766            Clothes Encounter   ca
# 2               queensland  61282269300       Investa Property Group   au
# 3                  ontario  18775896640               Timmins Garage  com
# 4                      NaN          NaN              Destinate Group   ca
# 5                  alberta  14032878770                    Iron Crow   ca
# 6                  ontario  19053690553  SpringBoard Data Management  com
# 7                  ontario  19054940660         STONE AND TILES R US  com
# 8                  ontario  18076834405                    MDAC CPAP  com
# 9                  ontario  16477257799        Micacchi Architecture   ca
# 10                manitoba  12042989266        SKI Collision & Glass  com
# 11            saskatchewan  13069900067          Liberte Light Dance  com
# 12  north rhine-westphalia   4921319280            Neusser Bauverein   de
# 13                     NaN  16133893437               Unity Sod Farm  com
# 14                 ontario  18882362646          Royal Canadian Mint  com
#
#                                           s_category Unnamed: 11 Unnamed: 12  \
# 0                                                NaN         NaN         NaN
# 1                      Shoes & Other Footwear Stores         NaN         NaN
# 2                             Real Estate Developers         NaN         NaN
# 3                 Automobile Dealers & Manufacturers         NaN         NaN
# 4                                Business Consulting         NaN         NaN
# 5                                   Furniture Stores         NaN         NaN
# 6                                     Data Solutions         NaN         NaN
# 7                                         Tile Store         NaN         NaN
# 8                       Medical Supply Manufacturers         NaN         NaN
# 9                Architects & Architectural Services         NaN         NaN
# 10                                   Auto Body Shops         NaN         NaN
# 11                                     Dance Schools         NaN         NaN
# 12  Executive, Legislative & Government Institutions         NaN         NaN
# 13                    Farms & Agriculture Production         NaN         NaN
# 14                          Watches & Jewelry Stores         NaN         NaN
#
#     Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16
# 0           NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN
# 5           NaN         NaN         NaN         NaN
# 6           NaN         NaN         NaN         NaN
# 7           NaN         NaN         NaN         NaN
# 8           NaN         NaN         NaN         NaN
# 9           NaN         NaN         NaN         NaN
# 10          NaN         NaN         NaN         NaN
# 11          NaN         NaN         NaN         NaN
# 12          NaN         NaN         NaN         NaN
# 13          NaN         NaN         NaN         NaN
# 14          NaN         NaN         NaN         NaN

# %% [markdown]
# Since there are several columns which consist of NaN values, I eliminated them.

# %%
web_ds.drop(web_ds.iloc[:, 11:], inplace = True, axis = 1)
# web_ds.head(15)

# %% [markdown]
# Since we want the dataset to be organised by the company names, I will check the percentage of unique company names.

# %%
print('Unqiue company names in the dataset: ',np.round(len(web_ds['legal_name'].unique())/web_ds.shape[0]*100, 2),'%')
# Out:
# Unqiue company names in the dataset:  42.53 %

# %% [markdown]
# I noticed that less than half of the dataset consists of unique company names. I explored the dataset using Excel and noticed that there are many company names assigned to a NaN value. This, I checked the percentage of NaN values in the company names.

# %%
print('NaN values percentage in company names: ',np.round(web_ds['legal_name'].isnull().sum()/web_ds.shape[0]*100, 2),'%')
# Out:
# NaN values percentage in company names:  55.61 %

# %% [markdown]
# Since more than half of the companies have their names missing, I will eliminate them, since the company name is the most important detail so we can't work with missing values.

# %%
# web_ds = web_ds.set_index("legal_name")
web_ds.dropna(subset=['legal_name'], inplace=True)
print('NaN values percentage in company names: ',np.round(web_ds['legal_name'].isnull().sum()/web_ds.shape[0]*100, 2),'%')
# Out:
# NaN values percentage in company names:  0.0 %

# %% [markdown]
# Now that there are no NaN values left, I will eliminate the duplicate names and replace any NaN value with blank spaces. I will continue analysing the dataset and the unique values for each column.

# %%
web_ds = web_ds.drop_duplicates(subset=['legal_name'])
web_ds = web_ds.replace(np.nan, '', regex=True)
for column in web_ds.columns:
    print(column, ': unique values percentage :',np.round(len(web_ds[column].unique())/web_ds.shape[0]*100, 2),'%')
# Out:
# root_domain : unique values percentage : 100.0 %
# domain_suffix : unique values percentage : 1.03 %
# language : unique values percentage : 0.05 %
# legal_name : unique values percentage : 100.0 %
# main_city : unique values percentage : 15.82 %
# main_country : unique values percentage : 0.59 %
# main_region : unique values percentage : 2.39 %
# phone : unique values percentage : 91.36 %
# site_name : unique values percentage : 96.87 %
# tld : unique values percentage : 0.6 %
# s_category : unique values percentage : 1.84 %

# %%
web_ds['phone'] = web_ds['phone'].astype(str)
# web_ds = web_ds.transform(lambda x: x.str.lower())
web_ds.reset_index()
web_ds.head(15)
# Out:
#               root_domain domain_suffix language  \
# 2          investa.com.au        com.au       en
# 3       timminsgarage.com           com       en
# 4            destinate.ca            ca       en
# 6       springboarddm.com           com       en
# 8            mdaccpap.com           com       en
# 11  libertelightdance.com           com       en
# 13       unitysodfarm.com           com       en
# 14            cdncoin.com           com       en
# 15       parlourcoffee.ca            ca       en
# 16   freshdishcatering.ca            ca       en
# 18     cityhomecomfort.ca            ca       en
# 19    garderiemirabel.com           com       fr
# 20            ochsner.org           org       en
# 21        runningfree.com           com       en
# 22      gamudaland.com.my        com.my       en
#
#                                     legal_name      main_city   main_country  \
# 2   Investa Wholesale Funds Management Limited       brisbane      australia
# 3                          Timmins Garage Inc.        timmins         canada
# 4                         Destinate Group Ltd.                        Canada
# 6                          The Hershey Company    mississauga         canada
# 8                                MDAC CPAP INC    thunder bay         canada
# 11   LIBERTE LIGHT DANCE, SCHOOL OF DANCE INC.      moose jaw         canada
# 13                         Unity Sod Farm Ltd.
# 14                        HUDSON'S BAY COMPANY  richmond hill         canada
# 15                         Parlour Coffee Ltd.       winnipeg         canada
# 16                       Maduro Coffee Company      saskatoon         canada
# 18                      City Home Comfort Inc.        toronto         canada
# 19                    Le Bon Roi Dagobert Inc.        mirabel         canada
# 20                             Ochsner Company    new orleans  united states
# 21                    Running Free Sports Inc.          poles        ireland
# 22                     Gamuda Land Vietnam LLC    johor bahru       malaysia
#
#      main_region        phone                    site_name  tld  \
# 2     queensland  61282269300       Investa Property Group   au
# 3        ontario  18775896640               Timmins Garage  com
# 4                                          Destinate Group   ca
# 6        ontario  19053690553  SpringBoard Data Management  com
# 8        ontario  18076834405                    MDAC CPAP  com
# 11  saskatchewan  13069900067          Liberte Light Dance  com
# 13                16133893437               Unity Sod Farm  com
# 14       ontario  18882362646          Royal Canadian Mint  com
# 15      manitoba  12049427679               Parlour Coffee   ca
# 16  saskatchewan  13062625586          Fresh Dish Catering   ca
# 18       ontario  14165568368            City Home Comfort   ca
# 19        quebec  15143472721           Garderie Educative  com
# 20     louisiana  18666247637               Ochsner Health  org
# 21        ulster  14164103733                 Running Free  com
# 22         johor  60374913200                  Gamuda Land   my
#
#                             s_category
# 2               Real Estate Developers
# 3   Automobile Dealers & Manufacturers
# 4                  Business Consulting
# 6                       Data Solutions
# 8         Medical Supply Manufacturers
# 11                       Dance Schools
# 13      Farms & Agriculture Production
# 14            Watches & Jewelry Stores
# 15                  Coffee & Tea Shops
# 16                 Catering & Delivery
# 18          Heating & Air Conditioning
# 19                     Daycare Centers
# 20     Clinics - Surgeons & Physicians
# 21       Shoes & Other Footwear Stores
# 22                             Resorts

# %% [markdown]
# I will do the same thing for the other two datasets. </br>
# </br>
# </br>
# **<font size="4"> FACEBOOK DATASET: </font>**

# %%
fb_ds = pd.read_csv('/kaggle/input/soleadify-dataset/facebook dataset.csv', error_bad_lines=False, low_memory=False, warn_bad_lines=False)
print('no. of rows: ',fb_ds.shape[0])
print('no. of columns: ', fb_ds.shape[1])
# Out:
# no. of rows:  71167
# no. of columns:  16

# %% [markdown]
# I explored this dataset using Excel and noticed 72000 rows. Some rows where lost due to the reading errors which I couldn't solve. </br>
# I also converted the phone number values from float to integer.

# %%
print('Unqiue company names in the dataset: ',np.round(len(fb_ds['name'].unique())/fb_ds.shape[0]*100, 2),'%')
print('NaN values percentage in company names: ',np.round(fb_ds['name'].isnull().sum()/fb_ds.shape[0]*100, 2),'%')
# Out:
# Unqiue company names in the dataset:  99.76 %
# NaN values percentage in company names:  0.0 %

# %%
fb_ds = fb_ds.drop_duplicates(subset=['name'])
# print('Unqiue company names in the dataset: ',np.round(len(fb_ds['name'].unique())/fb_ds.shape[0]*100, 2),'%')
# print(fb_ds)
for column in fb_ds.columns:
    print(column, ': unique values percentage :',np.round(len(fb_ds[column].unique())/fb_ds.shape[0]*100, 2),'%')
# Out:
# domain : unique values percentage : 100.0 %
# address : unique values percentage : 79.34 %
# categories : unique values percentage : 14.17 %
# city : unique values percentage : 8.89 %
# country_code : unique values percentage : 0.18 %
# country_name : unique values percentage : 0.16 %
# description : unique values percentage : 37.72 %
# email : unique values percentage : 27.79 %
# link : unique values percentage : 100.0 %
# name : unique values percentage : 100.0 %
# page_type : unique values percentage : 0.01 %
# phone : unique values percentage : 62.25 %
# phone_country_code : unique values percentage : 0.14 %
# region_code : unique values percentage : 0.61 %
# region_name : unique values percentage : 0.96 %
# zip_code : unique values percentage : 36.5 %

# %%
fb_ds['phone'] = fb_ds['phone'].replace('',0,regex=True)
fb_ds['phone'] = fb_ds['phone'].fillna(0).astype(int)
fb_ds['phone'] = fb_ds['phone'].replace(0,'',regex=True)
fb_ds['phone'] = fb_ds['phone'].astype(str)

# %% [markdown]
# Since I noticed that this dataset features more than one category for most of the companies, I inserted these categories in lists.

# %%
fb_ds = fb_ds.replace(np.nan, '', regex=True)
fb_ds['categories'] = fb_ds['categories'].transform(lambda x: x.split('|'))
fb_ds.head(15)
# Out:
#                      domain  \
# 0        euro-hygiene-34.fr
# 1   lakesidehomeservices.ca
# 2         rossiterboats.com
# 3      caa-architecture.com
# 4             apexsurety.ca
# 5            collins-cc.edu
# 6           dovercheese.com
# 7        alphascientific.ca
# 8            modernmama.com
# 9          unitysodfarm.com
# 10     healthability.org.au
# 11        houseofthunder.ca
# 12         brokenspirits.ca
# 13        downeastcoffee.ca
# 14    remax-royaljordan.com
#
#                                               address  \
# 0   134 rue entrepreneurs, za du vigné, 30420, cal...
# 1
# 2
# 3   601 cordova st w # 270, v6b 1g1, vancouver, bc...
# 4   unit 3 - 4 donald street, r3l 2t7, winnipeg, m...
# 5
# 6   307 main street, n0a 1n0, port dover, on, cana...
# 7   8623 granville street unit 143, v6p 5a2, vanco...
# 8
# 9   2989 unity road, k0h 1m0, kingston, on, canada...
# 10  917 main road, 3095, eltham, vic, australia, v...
# 11  4746-41 st, t4v 0z6, camrose, ab, canada, alberta
# 12  #4 – 3320 14 avenue ne, t2a 6j4, calgary, ab, ...
# 13  3935, route nb-115, e4v 2g1, notre dame, nb, c...
# 14
#
#                                            categories        city  \
# 0                                                  []   calvisson
# 1   [Appliance Repair & Maintenance, Home Builders...
# 2      [Boats & Yachts Dealers, Boat Tours & Cruises]
# 3   [Architects & Architectural Services, Other En...   vancouver
# 4                                                  []    winnipeg
# 5   [Other schools, High Schools, Community Center...
# 6                                                  []  port dover
# 7                      [Medical Supply Manufacturers]   vancouver
# 8                                    [Book Publisher]
# 9   [Agriculture & Farm Associations, Garden Equip...
# 10  [Security Guards & Patrol Services, Dentists &...      eltham
# 11    [Clothing Stores, Motorcycle Dealers & Rentals]     camrose
# 12                   [Distilleries & Malt Processing]     calgary
# 13                               [Coffee & Tea Shops]
# 14  [Real Estate - Agents & Managers, Real Estate ...
#
#    country_code country_name  \
# 0            fr       france
# 1            ca
# 2
# 3            ca       canada
# 4            ca       canada
# 5
# 6            ca       canada
# 7            ca       canada
# 8
# 9            ca
# 10           au    australia
# 11           ca       canada
# 12           ca       canada
# 13           ca
# 14           ca
#
#                                           description  \
# 0
# 1
# 2   At Rossiter Boats we build semi-custom power b...
# 3
# 4
# 5
# 6   The Dover Cheese Shop is a food lover’s paradi...
# 7   www.alphascientific.ca Alpha Scientific Repair...
# 8
# 9   Kingston's local supplier of quality sod, seed...
# 10
# 11
# 12
# 13  We are dedicated to consistent small-batch roa...
# 14
#
#                          email                             link  \
# 0                                    https://euro-hygiene-34.fr
# 1                               https://lakesidehomeservices.ca
# 2       info@rossiterboats.com         http://rossiterboats.com
# 3   office@caa-arcitecture.com      http://caa-architecture.com
# 4                                         https://apexsurety.ca
# 5                                        https://collins-cc.edu
# 6         info@dovercheese.com           http://dovercheese.com
# 7     sales@alphascientific.ca        http://alphascientific.ca
# 8                               https://modernmama.com/edmonton
# 9        info@unitysodfarm.com          http://unitysodfarm.com
# 10                                 https://healthability.org.au
# 11                                    https://houseofthunder.ca
# 12                                     https://brokenspirits.ca
# 13     roasters@bellaliant.com         http://downeastcoffee.ca
# 14                                https://remax-royaljordan.com
#
#                                      name      page_type        phone  \
# 0                            Euro Hygiène  LocalBusiness
# 1                  Lakeside Home Services  LocalBusiness  16138318840
# 2                          Rossiter Boats  LocalBusiness
# 3   Chandler Associates Architecture Inc.  LocalBusiness  16046873390
# 4            Apex Surety & Insurance Ltd.  LocalBusiness  12045602508
# 5         Collins Career Technical Center  LocalBusiness
# 6                   The Dover Cheese Shop  LocalBusiness
# 7   Alpha Scientific Repair Services Ltd.  LocalBusiness  16046903380
# 8                    Modern Mama Edmonton         Person
# 9                      Unity Sod Farm Ltd  LocalBusiness  16133893437
# 10                          HealthAbility  LocalBusiness
# 11                       House Of Thunder  LocalBusiness  17806082000
# 12              Broken Spirits Distillery  LocalBusiness  14033897845
# 13                       Down East Coffee  LocalBusiness  15065769292
# 14                RE/MAX ROYAL JORDAN INC  LocalBusiness  15146946900
#
#    phone_country_code region_code       region_name  zip_code
# 0                             occ         occitanie     30420
# 1                  ca
# 2
# 3                  ca          bc  british columbia   v6b 1g1
# 4                  ca          mb          manitoba   r3l 2t7
# 5
# 6                              on           ontario   n0a 1n0
# 7                  ca          bc  british columbia   v6p 5a2
# 8
# 9                  ca
# 10                            vic          victoria  victoria
# 11                 ca          ab           alberta   t4v 0z6
# 12                 ca          ab           alberta   t2a 6j4
# 13                 ca
# 14                 ca

# %% [markdown]
# **<font size="4"> GOOGLE DATASET: </font>**

# %%
ggl_ds = pd.read_csv('/kaggle/input/soleadify-dataset/google dataset.csv', error_bad_lines=False, low_memory=False, warn_bad_lines=False)
print('no. of rows: ',ggl_ds.shape[0])
print('no. of columns: ', ggl_ds.shape[1])
# Out:
# no. of rows:  346925
# no. of columns:  15

# %%
print('Unqiue company names in the dataset: ',np.round(len(ggl_ds['name'].unique())/ggl_ds.shape[0]*100, 2),'%')
print('NaN values percentage in company names: ',np.round(ggl_ds['name'].isnull().sum()/ggl_ds.shape[0]*100, 2),'%')
# Out:
# Unqiue company names in the dataset:  99.27 %
# NaN values percentage in company names:  0.01 %

# %%
ggl_ds.dropna(subset=['name'], inplace=True)
print('NaN values percentage in company names: ',np.round(ggl_ds['name'].isnull().sum()/ggl_ds.shape[0]*100, 2),'%')
# Out:
# NaN values percentage in company names:  0.0 %

# %% [markdown]
# I removed the '+' symbol in the phone numbers so they should correspond to the phone numbers in the other datasets.

# %%
ggl_ds['phone'] = ggl_ds['phone'].transform(lambda x: x.str.replace('+', '',regex=True))
ggl_ds['phone'] = ggl_ds['phone'].transform(lambda x: x.str.strip())
ggl_ds = ggl_ds.replace(np.nan, '', regex=True)
ggl_ds['phone'] = ggl_ds['phone'].astype(str)

# %%
ggl_ds.head(15)
# Out:
#                                               address  \
# 0   28 Central Coast Hwy, West Gosford NSW 2250, A...
# 1    400 Scott St, St. Catharines, ON L2M 3W2, Canada
# 2       191 Pleasant St, Yarmouth, NS B5A 2J9, Canada
# 3   11040 Santa Monica Blvd Suite 370, Los Angeles...
# 4
# 5                         Ferndale, MI, United States
# 6             321 Kent St, Sydney NSW 2000, Australia
# 7           55 S Cleveland Ave, Westerville, OH 43081
# 8   4050 S Torrey Pines Dr, Las Vegas, NV 89103, U...
# 9   7+ years in business · St Paul, MN, United States
# 10              125 Chesterfield Ln, Maumee, OH 43537
# 11                    29 Clement St, Nashua, NH 03060
# 12         600 N Wolfe St #7-113, Baltimore, MD 21287
# 13               1800 Orleans St, Baltimore, MD 21287
# 14                200 N Wolfe St, Baltimore, MD 21287
#
#                                    category            city country_code  \
# 0                   Fabric-Based Home Goods         gosford           au
# 1                               Book Stores  st. catharines           ca
# 2         Other Building Material Retailers        yarmouth           ca
# 3                   Plastic Surgery Clinics     los angeles           us
# 4                       Catering & Delivery
# 5                               Pubs & Bars        ferndale           us
# 6   Insurance -  Agents, Carriers & Brokers          sydney           au
# 7                Preschools & Kindergartens     westerville           us
# 8                Preschools & Kindergartens       las vegas           us
# 9                Preschools & Kindergartens                           us
# 10               Preschools & Kindergartens          maumee           us
# 11               Preschools & Kindergartens          nashua           us
# 12                              Pediatrists       baltimore           us
# 13          Clinics - Surgeons & Physicians       baltimore
# 14                              Pediatrists       baltimore           us
#
#      country_name                                        name        phone  \
# 0       australia                      Spotlight West Gosford  61243355946
# 1          canada               Heritage Christian Book Store  19059374553
# 2          canada                        Pleasant Timber Mart  19027429181
# 3   united states          Skin Specifics Medical Spa West LA  18184268353
# 4                                               Lakay express
# 5   united states  B. Nektar Meadery - Taproom & Headquarters  13137446323
# 6       australia                                   icare NSW
# 7   united states           South Cleveland Avenue KinderCare  16148990026
# 8   united states                     Torrey Pines KinderCare  17023670822
# 9                                      Meadowlands KinderCare  16514296316
# 10  united states                           Maumee KinderCare  14198938206
# 11  united states             KinderCare at Rivier University  16038880442
# 12  united states                               Brem Henry MD  14109556406
# 13  united states   The Johns Hopkins Hospital Emergency Room  14109555000
# 14  united states                  Ann O'Shea Scheimann, M.D.  14439975437
#
#    phone_country_code                                        raw_address  \
# 0                  au                        West Gosford NSW, Australia
# 1                  ca                   400 Scott St · In Grantham Plaza
# 2                  ca        7+ years in business · Yarmouth, NS, Canada
# 3                  us  7+ years in business · 11040 Santa Monica Blvd...
# 4
# 5                  us                        Ferndale, MI, United States
# 6                                                  Sydney NSW, Australia
# 7                                 7+ years in business · Westerville, OH
# 8                  us  7+ years in business · Las Vegas, NV, United S...
# 9                  us  7+ years in business · St Paul, MN, United States
# 10                                     7+ years in business · Maumee, OH
# 11                                                            Nashua, NH
# 12                                                         Baltimore, MD
# 13                                        Baltimore, MD · (410) 955-5000
# 14                                                         Baltimore, MD
#
#           raw_phone region_code      region_name  \
# 0   +61 2 4335 5946         nsw  new south wales
# 1   +1 905-937-4553          on          ontario
# 2   +1 902-742-9181          ns      nova scotia
# 3   +1 818-426-8353          ca       california
# 4
# 5   +1 313-744-6323          mi         michigan
# 6                           nsw  new south wales
# 7    (614) 899-0026          oh             ohio
# 8   +1 702-367-0822          nv           nevada
# 9    (651) 429-6316
# 10   (419) 893-8206          oh             ohio
# 11   (603) 888-0442          nh    new hampshire
# 12   (410) 955-6406          md         maryland
# 13   (410) 955-5000          md         maryland
# 14   (443) 997-5437          md         maryland
#
#                                                  text zip_code  \
# 0   4.1 (766) · Craft store West Gosford NSW, Aust...     2250
# 1   4.7 (100) · Book store 400 Scott St · In Grant...  l2m 3w2
# 2   4.7 (40) · Building materials store 7+ years i...  b5a 2j9
# 3   4.3 (15) · Medical spa 7+ years in business · ...    90025
# 4          5.0 (1) · Mobile caterer Open ⋅ Closes 9PM
# 5   4.8 (296) · $$ · Bar Ferndale, MI, United Stat...
# 6   2.3 (187) · Insurance company Sydney NSW, Aust...     2000
# 7   3.6 (20) · Preschool 7+ years in business · We...    43081
# 8   3.8 (11) · Preschool 7+ years in business · La...    89103
# 9   4.8 (9) · Kindergarten 1000 Meadowlands Dr Clo...
# 10  4.6 (10) · Preschool 7+ years in business · Ma...    43537
# 11  5.0 (1) · Day care center Nashua, NH Closed ⋅ ...    03060
# 12  No reviews · Neurologist Baltimore, MD (410) 9...    21287
# 13  Emergency room Baltimore, MD · (410) 955-5000 ...    21287
# 14  No reviews · Pediatrician Baltimore, MD (443) ...    21287
#
#                  domain
# 0   spotlightstores.com
# 1       bookmanager.com
# 2         timbermart.ca
# 3             linktr.ee
# 4             linktr.ee
# 5             linktr.ee
# 6      icare.nsw.gov.au
# 7        kindercare.com
# 8        kindercare.com
# 9        kindercare.com
# 10       kindercare.com
# 11       kindercare.com
# 12  hopkinsmedicine.org
# 13  hopkinsmedicine.org
# 14  hopkinsmedicine.org

# %% [markdown]
# **<font size="4"> MERGING THE THREE DATASETS </font>**
# </br>
# </br>
# </br>
# Now that we finally have all the datasets containing unique company names, we can further modify the company names by removing abbreviations like 'LTD' or 'INC' so we'll know that a company which is called, for example, 'Facebook Inc.' is the same one with 'Facebook'.

# %%
abbreviations = ['ltd','inc','llc','org','gmbh','corp','mfg','mfrs','ltd.','inc.','llc.','org.','gmbh.','corp.','mfg.','mfrs.',',','-','.']

web_ds['legal_name'] = web_ds['legal_name'].transform(lambda x: x.str.lower())
web_ds['legal_name'] = web_ds['legal_name'].apply(lambda x: ' '.join([word for word in x.split() if word not in abbreviations]))

fb_ds['name'] = fb_ds['name'].transform(lambda x: x.str.lower())
fb_ds['name'] = fb_ds['name'].apply(lambda x: ' '.join([word for word in x.split() if word not in abbreviations]))

ggl_ds['name'] = ggl_ds['name'].transform(lambda x: x.str.lower())
ggl_ds['name'] = ggl_ds['name'].apply(lambda x: ' '.join([word for word in x.split() if word not in abbreviations]))

# %% [markdown]
# I will now determine the percentage of common company names in the three datasets.

# %%
intersect = np.intersect1d(web_ds['legal_name'], fb_ds['name'])
intersect = np.intersect1d(ggl_ds['name'], intersect)
print('common companies in all three datasets: ',len(intersect))
print('percentage of common companies in the website dataset: ', np.round(len(intersect)/len(web_ds['legal_name'])*100, 2),'%')
print('percentage of common companies in the Facebook dataset: ', np.round(len(intersect)/len(fb_ds['name'])*100, 2), '%')
print('percentage of common companies in the Google dataset:', np.round(len(intersect)/len(ggl_ds['name'])*100, 2), '%')
# Out:
# common companies in all three datasets:  11637
# percentage of common companies in the website dataset:  38.05 %
# percentage of common companies in the Facebook dataset:  16.39 %
# percentage of common companies in the Google dataset: 3.35 %

# %% [markdown]
# Looks like most of the common companies are found in the website dataset, which is the smallest one. We'll get a pretty small merged dataset. I will rename the columns so there won't be any confusion, since in the Google and Facebook datasets the company names correspond to the 'name' column, the country names correspond to the 'country_name' column etc.

# %%
web_ds.columns = ['web_root_domain', 'web_domain_suffix', 'web_language', 'web_legal_name', 'web_main_city',
       'web_main_country', 'web_main_region', 'web_phone', 'web_site_name', 'web_tld',
       'web_category']
fb_ds.columns = ['fb_domain', 'fb_address', 'fb_categories', 'fb_city', 'fb_country_code',
       'fb_country_name', 'fb_description', 'fb_email', 'fb_link', 'fb_name', 'fb_page_type',
       'fb_phone', 'fb_phone_country_code', 'fb_region_code', 'fb_region_name',
       'fb_zip_code']
ggl_ds.columns = ['ggl_address', 'ggl_category', 'ggl_city', 'ggl_country_code', 'ggl_country_name', 'ggl_name',
       'ggl_phone', 'ggl_phone_country_code', 'ggl_raw_address', 'ggl_raw_phone',
       'ggl_region_code', 'ggl_region_name', 'ggl_text', 'ggl_zip_code', 'ggl_domain']

# %% [markdown]
# I will now merge the three datasets.

# %%
ds = fb_ds.merge(ggl_ds, left_on="fb_name", right_on="ggl_name")
ds = ds.merge(web_ds, left_on='ggl_name', right_on='web_legal_name')
ds = ds.reset_index()
ds.head(15)
# Out:
#     index                  fb_domain  \
# 0       0    lakesidehomeservices.ca
# 1       1       caa-architecture.com
# 2       2              apexsurety.ca
# 3       3         alphascientific.ca
# 4       4           unitysodfarm.com
# 5       5          vintageautogp.com
# 6       6          shariffitness.com
# 7       7         powerstrokeltd.com
# 8       8   kingswaytransmission.com
# 9       9         parksiderentals.ca
# 10     10            playcaresrc.com
# 11     11      rubberduckyresort.com
# 12     12         wrenchautotech.com
# 13     13  orthopedicsatyourstep.com
# 14     14        edmontonspaving.com
#
#                                            fb_address  \
# 0
# 1   601 cordova st w # 270, v6b 1g1, vancouver, bc...
# 2   unit 3 - 4 donald street, r3l 2t7, winnipeg, m...
# 3   8623 granville street unit 143, v6p 5a2, vanco...
# 4   2989 unity road, k0h 1m0, kingston, on, canada...
# 5   34007 twp rd 713a, county of gp no 1, t8x 4b7,...
# 6   1050 belcourt st, l1x 0g3, pickering, on, cana...
# 7   18-34 wrangler place se, t1x 0l7, calgary, ab,...
# 8   195 westney road south, unit 5, l1s 2c9, ajax,...
# 9   birds hill park hwy 206, r0e 0k0, winnipeg, mb...
# 10    215 s apopka ave, 34452, inverness, fl, florida
# 11  1069 road 76.5, r0c 3e0, warren, mb, canada, m...
# 12  2565 steeles ave e unit#28, l6t 4l6, brampton,...
# 13
# 14
#
#                                         fb_categories         fb_city  \
# 0   [Appliance Repair & Maintenance, Home Builders...
# 1   [Architects & Architectural Services, Other En...       vancouver
# 2                                                  []        winnipeg
# 3                      [Medical Supply Manufacturers]       vancouver
# 4   [Agriculture & Farm Associations, Garden Equip...
# 5   [Auto Services, Auto Parts Store, Automobile D...  grande prairie
# 6   [Personal Trainer, Fitness & Health Centers, F...       pickering
# 7             [Towing Wrecking & Roadside Assistance]         calgary
# 8   [Auto Services, Auto Parts Store, Automobile D...            ajax
# 9   [Boat Rental & Chartering Services, Boat Tours...        winnipeg
# 10  [Daycare Centers, Daycare Centers, Preschools ...       inverness
# 11                   [RV Parks & Campgrounds, Hotels]
# 12      [Auto Services, Auto Parts Store, Locksmiths]        brampton
# 13                                                 []
# 14  [Home Builders & Renovation Contractors, Aspha...
#
#    fb_country_code fb_country_name  \
# 0               ca
# 1               ca          canada
# 2               ca          canada
# 3               ca          canada
# 4               ca
# 5               ca          canada
# 6               ca          canada
# 7               ca          canada
# 8               ca          canada
# 9               ca          canada
# 10              us   united states
# 11
# 12              ca          canada
# 13              ca
# 14              ca
#
#                                        fb_description  \
# 0
# 1
# 2
# 3   www.alphascientific.ca Alpha Scientific Repair...
# 4   Kingston's local supplier of quality sod, seed...
# 5   Vintage Auto is a company that rebuilds vintag...
# 6
# 7
# 8   Kingsway Transmission has been providing excep...
# 9   All rentals come with a trailer so you can go ...
# 10
# 11  Family Campground located approx 20 mins from ...
# 12    It's broken we fix it All your automotive needs
# 13  Orthopedics At Your Step, Inc. is a mobile ort...
# 14
#
#                           fb_email                           fb_link  ...  \
# 0                                    https://lakesidehomeservices.ca  ...
# 1       office@caa-arcitecture.com       http://caa-architecture.com  ...
# 2                                              https://apexsurety.ca  ...
# 3         sales@alphascientific.ca         http://alphascientific.ca  ...
# 4            info@unitysodfarm.com           http://unitysodfarm.com  ...
# 5         elesko@vintageautogp.com          http://vintageautogp.com  ...
# 6                                          https://shariffitness.com  ...
# 7                                         https://powerstrokeltd.com  ...
# 8   kingswaytransmission@gmail.com   http://kingswaytransmission.com  ...
# 9                                          http://parksiderentals.ca  ...
# 10                                           https://playcaresrc.com  ...
# 11      info@rubberduckyresort.com      http://rubberduckyresort.com  ...
# 12         info@wrenchautotech.com         http://wrenchautotech.com  ...
# 13  info@orthopedicsatyourstep.com  http://orthopedicsatyourstep.com  ...
# 14                                       https://edmontonspaving.com  ...
#
#    web_domain_suffix web_language                      web_legal_name  \
# 0                 ca           en              lakeside home services
# 1                com           en    chandler associates architecture
# 2                 ca           en             apex surety & insurance
# 3                 ca           en    alpha scientific repair services
# 4                com           en                      unity sod farm
# 5                com           en   vintage auto restoration services
# 6                com           en                      sharif fitness
# 7                com           en           power stroke truck centre
# 8                com           en               kingsway transmission
# 9                 ca           en                    parkside rentals
# 10               com           en    playcare school readiness center
# 11               com           en  rubber ducky resort and campground
# 12               com           en                    wrench auto tech
# 13               com           en           orthopedics at your step,
# 14               com           en       edmonton's paving and asphalt
#
#    web_main_city web_main_country   web_main_region    web_phone  \
# 0    stittsville           canada           ontario  16138318840
# 1      vancouver           canada  british columbia  16046873325
# 2       winnipeg           canada          manitoba  12045602508
# 3      vancouver           canada  british columbia  16046903380
# 4                                                    16133893437
# 5                                                    17808148233
# 6      pickering           canada           ontario  16474956405
# 7                                                    14035707782
# 8           ajax           canada           ontario  19054288940
# 9         dugald           canada          manitoba  12042325434
# 10     inverness    united states           florida  13523413888
# 11        warren           canada           ontario  12043225286
# 12                                                   19054972734
# 13       toronto           canada           ontario  16473883100
# 14      edmonton           canada           alberta  17807174235
#
#                         web_site_name web_tld  \
# 0              Lakeside Home Services      ca
# 1                            Chandler     com
# 2                       INSURANCEAPEX      ca
# 3                    Alpha Scientific      ca
# 4                      Unity Sod Farm     com
# 5   Vintage Auto Restoration Services     com
# 6                      SHARIF FITNESS     com
# 7           Power Stroke Truck Centre     com
# 8               Kingsway Transmission     com
# 9                    Parkside Rentals      ca
# 10                           Playcare     com
# 11   Rubber Ducky Resort & Campground     com
# 12                                        com
# 13                    Orthoatyourstep     com
# 14                   Edmontons Paving     com
#
#                            web_category
# 0        Appliance Repair & Maintenance
# 1   Architects & Architectural Services
# 2            Liability Insurance Agency
# 3          Medical Supply Manufacturers
# 4        Farms & Agriculture Production
# 5              Auto Restoration Service
# 6                     Martial Arts Gyms
# 7                         Auto Services
# 8                         Auto Services
# 9     Boat Rental & Chartering Services
# 10           Preschools & Kindergartens
# 11                              Resorts
# 12            Auto Electrical Equipment
# 13         Medical Supply Manufacturers
# 14            Asphalt & Paving Services
#
# [15 rows x 43 columns]

# %% [markdown]
# The columns which we are interesed in are: category, region, country, city, phone, compnay name. Since we already have 100% accuracy in the company name column, we well check the other ones. **The Facebook dataset features multiple categories for almost every company, so if any of the categories is present in the other datasets, it will count as a match.**

# %%
ds['company_match'] = ((ds['web_legal_name'] == ds['ggl_name'])&(ds['ggl_name'] == ds['fb_name']))


ds['country_match'] = ((ds['web_main_country'] == ds['fb_country_name'])&(ds['fb_country_name'] == ds['ggl_country_name']))

ds['region_match'] = ((ds['web_main_region'] == ds['fb_region_name'])&(ds['fb_region_name'] == ds['ggl_region_name']))

ds['phone_match'] = ((ds['web_phone'] == ds['fb_phone'])&(ds['fb_phone'] == ds['ggl_phone']))

ds['city_match'] = ((ds['web_main_city'] == ds['fb_city']) & (ds['fb_city'] == ds['ggl_city']))

true = 0
for i in range(ds.shape[0]):
    row = ds.iloc[i]
    for item in row['fb_categories']:
        if row['ggl_category'] == item and row['web_category'] == item:
            true += 1


data = [['Accuracy', (ds['company_match'].value_counts()/ds.shape[0]*100).iloc[0], (np.round(ds['country_match'].value_counts()/ds.shape[0]*100,2)).iloc[0],
     (np.round(ds['region_match'].value_counts()/ds.shape[0]*100,2)).iloc[0], (np.round(ds['city_match'].value_counts()/ds.shape[0]*100,2)).iloc[0],
         (np.round(ds['phone_match'].value_counts()/ds.shape[0]*100,2)).iloc[0], np.round(true/ds.shape[0]*100,2)]]
table = tabulate(data, headers=['','Company Match', 'Country Match', 'Region Match', 'City Match', 'Phone Match', 'Category Match'], tablefmt='orgtbl')
print(table)
# Out:
# |          |   Company Match |   Country Match |   Region Match |   City Match |   Phone Match |   Category Match |
# |----------+-----------------+-----------------+----------------+--------------+---------------+------------------|
# | Accuracy |             100 |           55.03 |          52.88 |        56.12 |         50.31 |            20.26 |

# %% [markdown]
# This doesn't look good. We get around 50% accuracy for all the columns expect for the category column, where the accuracy is even lower, and the company name column. That's mainly becuase there are missing values in the columns. For example, if we find out from the *'fb_country_name'* column that a company is located in France, but the '*ggl_country_name*' corresponding column has a missing value, it will count as a non-match.
# * First, we merge the Facebook and Google datasets, replace any missing value with the correct value to get a higher accuracy.
# * The resulting dataset will be merged with the website dataset, repeating these steps.

# %%
ds.to_csv('first_complete_dataset.csv')

# %% [markdown]
# **<font size="4"> MERGING THE FACEBOOK AND GOOGLE DATASETS </font>**

# %%
intersect = np.intersect1d(ggl_ds['ggl_name'], fb_ds['fb_name'])
print('common companies in all three datasets: ',len(intersect))
print('percentage of common companies in the Facebook dataset: ', np.round(len(intersect)/len(fb_ds['fb_name'])*100, 2), '%')
print('percentage of common companies in the Google dataset:', np.round(len(intersect)/len(ggl_ds['ggl_name'])*100, 2), '%')
# Out:
# common companies in all three datasets:  40900
# percentage of common companies in the Facebook dataset:  57.61 %
# percentage of common companies in the Google dataset: 11.79 %

# %% [markdown]
# We can see that more than half of the Facebook companies can be found in the Google dataset, and moreover, we get a 4 times bigger dataset than the previos one which contains all the three datasets.

# %%
ds_fb_ggl = fb_ds.merge(ggl_ds, left_on="fb_name", right_on="ggl_name")
ds_fb_ggl.head(15)
# Out:
#                   fb_domain  \
# 0        euro-hygiene-34.fr
# 1   lakesidehomeservices.ca
# 2         rossiterboats.com
# 3      caa-architecture.com
# 4             apexsurety.ca
# 5            collins-cc.edu
# 6           dovercheese.com
# 7        alphascientific.ca
# 8          unitysodfarm.com
# 9      healthability.org.au
# 10        houseofthunder.ca
# 11         brokenspirits.ca
# 12        downeastcoffee.ca
# 13           apexglasson.ca
# 14             marilees.com
#
#                                            fb_address  \
# 0   134 rue entrepreneurs, za du vigné, 30420, cal...
# 1
# 2
# 3   601 cordova st w # 270, v6b 1g1, vancouver, bc...
# 4   unit 3 - 4 donald street, r3l 2t7, winnipeg, m...
# 5
# 6   307 main street, n0a 1n0, port dover, on, cana...
# 7   8623 granville street unit 143, v6p 5a2, vanco...
# 8   2989 unity road, k0h 1m0, kingston, on, canada...
# 9   917 main road, 3095, eltham, vic, australia, v...
# 10  4746-41 st, t4v 0z6, camrose, ab, canada, alberta
# 11  #4 – 3320 14 avenue ne, t2a 6j4, calgary, ab, ...
# 12  3935, route nb-115, e4v 2g1, notre dame, nb, c...
# 13  41 harwood ave. south, l1s2b8, ajax, on, canad...
# 14  170 hwy 20 w unit 5, l0s1e0, fonthill, on, can...
#
#                                         fb_categories     fb_city  \
# 0                                                  []   calvisson
# 1   [Appliance Repair & Maintenance, Home Builders...
# 2      [Boats & Yachts Dealers, Boat Tours & Cruises]
# 3   [Architects & Architectural Services, Other En...   vancouver
# 4                                                  []    winnipeg
# 5   [Other schools, High Schools, Community Center...
# 6                                                  []  port dover
# 7                      [Medical Supply Manufacturers]   vancouver
# 8   [Agriculture & Farm Associations, Garden Equip...
# 9   [Security Guards & Patrol Services, Dentists &...      eltham
# 10    [Clothing Stores, Motorcycle Dealers & Rentals]     camrose
# 11                   [Distilleries & Malt Processing]     calgary
# 12                               [Coffee & Tea Shops]
# 13  [Glass & Mirror Stores, Home Builders & Renova...        ajax
# 14                  [Bridal Shops & Wedding Supplies]    fonthill
#
#    fb_country_code fb_country_name  \
# 0               fr          france
# 1               ca
# 2
# 3               ca          canada
# 4               ca          canada
# 5
# 6               ca          canada
# 7               ca          canada
# 8               ca
# 9               au       australia
# 10              ca          canada
# 11              ca          canada
# 12              ca
# 13              ca          canada
# 14              ca          canada
#
#                                        fb_description  \
# 0
# 1
# 2   At Rossiter Boats we build semi-custom power b...
# 3
# 4
# 5
# 6   The Dover Cheese Shop is a food lover’s paradi...
# 7   www.alphascientific.ca Alpha Scientific Repair...
# 8   Kingston's local supplier of quality sod, seed...
# 9
# 10
# 11
# 12  We are dedicated to consistent small-batch roa...
# 13  We are your custom glass and mirror specialist...
# 14  Marilee's Bridal - Niagara's favourite boutiqu...
#
#                       fb_email                          fb_link  \
# 0                                    https://euro-hygiene-34.fr
# 1                               https://lakesidehomeservices.ca
# 2       info@rossiterboats.com         http://rossiterboats.com
# 3   office@caa-arcitecture.com      http://caa-architecture.com
# 4                                         https://apexsurety.ca
# 5                                        https://collins-cc.edu
# 6         info@dovercheese.com           http://dovercheese.com
# 7     sales@alphascientific.ca        http://alphascientific.ca
# 8        info@unitysodfarm.com          http://unitysodfarm.com
# 9                                  https://healthability.org.au
# 10                                    https://houseofthunder.ca
# 11                                     https://brokenspirits.ca
# 12     roasters@bellaliant.com         http://downeastcoffee.ca
# 13         info@apexglasson.ca            http://apexglasson.ca
# 14           info@marilees.com              http://marilees.com
#
#                              fb_name  ...                          ggl_name  \
# 0                       euro hygiène  ...                      euro hygiène
# 1             lakeside home services  ...            lakeside home services
# 2                     rossiter boats  ...                    rossiter boats
# 3   chandler associates architecture  ...  chandler associates architecture
# 4            apex surety & insurance  ...           apex surety & insurance
# 5    collins career technical center  ...   collins career technical center
# 6              the dover cheese shop  ...             the dover cheese shop
# 7   alpha scientific repair services  ...  alpha scientific repair services
# 8                     unity sod farm  ...                    unity sod farm
# 9                      healthability  ...                     healthability
# 10                  house of thunder  ...                  house of thunder
# 11         broken spirits distillery  ...         broken spirits distillery
# 12                  down east coffee  ...                  down east coffee
# 13             apex glass and mirror  ...             apex glass and mirror
# 14                  marilee's bridal  ...                  marilee's bridal
#
#       ggl_phone ggl_phone_country_code  \
# 0
# 1   16138318840                     ca
# 2   15199861203                     ca
# 3   16046873390                     ca
# 4   12045602508                     ca
# 5   17408676641                     us
# 6   15197181201                     ca
# 7   16046903380                     ca
# 8   16133893437                     ca
# 9   61394309100                     au
# 10  17806082000                     ca
# 11  14033897845                     ca
# 12  15068556696                     ca
# 13  19054282537                     ca
# 14  19058926634                     ca
#
#                                       ggl_raw_address      ggl_raw_phone  \
# 0            3+ years in business · Calvisson, France  +33 4 66 04 02 00
# 1                                                        +1 613-831-8840
# 2                                Markdale, ON, Canada    +1 519-986-1203
# 3   5+ years in business · Vancouver, BC, Canada ·...    +1 604-687-3390
# 4                                      4 Donald St #3    +1 204-560-2508
# 5                       Chesapeake, OH, United States    +1 740-867-6641
# 6            Port Dover, ON, Canada · +1 519-718-1201    +1 519-718-1201
# 7                               Vancouver, BC, Canada    +1 604-690-3380
# 8                               Elginburg, ON, Canada    +1 613-389-3437
# 9                               Eltham VIC, Australia    +61 3 9430 9100
# 10              Camrose, AB, Canada · +1 780-608-2000    +1 780-608-2000
# 11                              3320 14 Ave NE Unit 4    +1 403-389-7845
# 12                                Moncton, NB, Canada    +1 506-855-6696
# 13                                   Ajax, ON, Canada    +1 905-428-2537
# 14        5+ years in business · Fonthill, ON, Canada    +1 905-892-6634
#
#    ggl_region_code   ggl_region_name  \
# 0              occ         occitanie
# 1
# 2               on           ontario
# 3               bc  british columbia
# 4               mb          manitoba
# 5
# 6               on           ontario
# 7               bc  british columbia
# 8
# 9              vic          victoria
# 10              ab           alberta
# 11              ab           alberta
# 12              nb     new brunswick
# 13              on           ontario
# 14              on           ontario
#
#                                              ggl_text ggl_zip_code  \
# 0   4.7 (3) · Pest control service 3+ years in bus...
# 1   5.0 (2) · Appliance repair service Closed ⋅ Op...
# 2   4.5 (4) · Boat builders Markdale, ON, Canada O...
# 3   4.5 (2) · Architect 5+ years in business · Van...      v6c 2g8
# 4   No reviews · Insurance broker 4 Donald St #3 O...      r3l 2t7
# 5   4.3 (16) · Technical school Chesapeake, OH, Un...
# 6   Cheese shop Port Dover, ON, Canada · +1 519-71...      n0a 1n0
# 7   No reviews · Medical equipment supplier Vancou...      v6p 5a3
# 8   3.9 (18) · Farm Elginburg, ON, Canada Closed ⋅...
# 9   4.2 (41) · Community health centre Eltham VIC,...         3095
# 10  Camrose, AB, Canada · +1 780-608-2000 Open ⋅ C...      t4v 0z6
# 11  5.0 (8) · Distillery 3320 14 Ave NE Unit 4 Clo...      t2a 6j4
# 12  4.6 (309) · $$ · Coffee shop Moncton, NB, Cana...      e1e 2c6
# 13  4.0 (48) · Glass & mirror shop Ajax, ON, Canad...      l1s 2b8
# 14  4.5 (73) · Bridal shop 5+ years in business · ...      l0s 1e5
#
#                  ggl_domain
# 0        euro-hygiene-34.fr
# 1   lakesidehomeservices.ca
# 2         rossiterboats.com
# 3      caa-architecture.com
# 4             apexsurety.ca
# 5            collins-cc.edu
# 6           dovercheese.com
# 7        alphascientific.ca
# 8          unitysodfarm.com
# 9      healthability.org.au
# 10        houseofthunder.ca
# 11         brokenspirits.ca
# 12        downeastcoffee.ca
# 13           apexglasson.ca
# 14             marilees.com
#
# [15 rows x 31 columns]

# %%
ds_fb_ggl['company_match'] = (ds_fb_ggl['ggl_name'] == ds_fb_ggl['fb_name'])

ds_fb_ggl['country_match'] = (ds_fb_ggl['fb_country_name'] == ds_fb_ggl['ggl_country_name'])

ds_fb_ggl['region_match'] =(ds_fb_ggl['fb_region_name'] == ds_fb_ggl['ggl_region_name'])

ds_fb_ggl['phone_match'] = (ds_fb_ggl['fb_phone'] == ds_fb_ggl['ggl_phone'])

ds_fb_ggl['city_match'] = (ds_fb_ggl['fb_city'] == ds_fb_ggl['ggl_city'])

true = 0
for i in range(ds_fb_ggl.shape[0]):
    row = ds_fb_ggl.iloc[i]
    for item in row['fb_categories']:
        if row['ggl_category'] == item:
            true += 1
            
data = [['Accuracy', (ds_fb_ggl['company_match'].value_counts()/ds_fb_ggl.shape[0]*100).iloc[0], 
         (np.round(ds_fb_ggl['country_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0],
         (np.round(ds_fb_ggl['region_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0], 
         (np.round(ds_fb_ggl['city_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0], 
         (np.round(ds_fb_ggl['phone_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0], 
          np.round(true/ds_fb_ggl.shape[0]*100,2)]]
table = tabulate(data, headers=['','Company Match', 'Country Match', 'Region Match', 'City Match', 'Phone Match', 'Category Match'], tablefmt='orgtbl')
print(table)
# Out:
# |          |   Company Match |   Country Match |   Region Match |   City Match |   Phone Match |   Category Match |
# |----------+-----------------+-----------------+----------------+--------------+---------------+------------------|
# | Accuracy |             100 |           66.06 |          64.35 |        58.26 |         58.08 |            35.13 |

# %% [markdown]
# Ok, this looks a bit better than the previous dataset, but the accuracy is still  low for all the columns. I will now fill the missing values.

# %%
def fill_missing_values(fb_column, ggl_column):
    ds_fb_ggl[fb_column] = ds_fb_ggl[fb_column].replace('',np.nan, regex=True)
    ds_fb_ggl[fb_column].fillna(ds_fb_ggl[ggl_column], inplace=True)
    ds_fb_ggl[ggl_column] = ds_fb_ggl[ggl_column].replace('',np.nan, regex=True)
    ds_fb_ggl[ggl_column].fillna(ds_fb_ggl[fb_column], inplace=True)

fill_missing_values('fb_country_name', 'ggl_country_name')
fill_missing_values('fb_region_name', 'ggl_region_name')
fill_missing_values('fb_city', 'ggl_city')
fill_missing_values('fb_phone', 'ggl_phone')

for i in range(ds_fb_ggl.shape[0]):
    if ds_fb_ggl.iloc[i].at['fb_categories'] == ['']:
        ds_fb_ggl.iloc[i].at['fb_categories'].remove('') 
        ds_fb_ggl.iloc[i].at['fb_categories'].append(ds_fb_ggl.iloc[i].at['ggl_category'])

# %% [markdown]
# Now let's see the results:

# %%
ds_fb_ggl['company_match'] = (ds_fb_ggl['ggl_name'] == ds_fb_ggl['fb_name'])

ds_fb_ggl['country_match'] = (ds_fb_ggl['fb_country_name'] == ds_fb_ggl['ggl_country_name'])

ds_fb_ggl['region_match'] =(ds_fb_ggl['fb_region_name'] == ds_fb_ggl['ggl_region_name'])

ds_fb_ggl['phone_match'] = (ds_fb_ggl['fb_phone'] == ds_fb_ggl['ggl_phone'])

ds_fb_ggl['city_match'] = (ds_fb_ggl['fb_city'] == ds_fb_ggl['ggl_city'])

true = 0
for i in range(ds_fb_ggl.shape[0]):
    row = ds_fb_ggl.iloc[i]
    for item in row['fb_categories']:
        if row['ggl_category'] == item:
            true += 1
            
data = [['Accuracy', (ds_fb_ggl['company_match'].value_counts()/ds_fb_ggl.shape[0]*100).iloc[0], 
         (np.round(ds_fb_ggl['country_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0],
         (np.round(ds_fb_ggl['region_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0], 
         (np.round(ds_fb_ggl['city_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0], 
         (np.round(ds_fb_ggl['phone_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0], 
          np.round(true/ds_fb_ggl.shape[0]*100,2)]]
table = tabulate(data, headers=['','Company Match', 'Country Match', 'Region Match', 'City Match', 'Phone Match', 'Category Match'], tablefmt='orgtbl')
print(table)
# Out:
# |          |   Company Match |   Country Match |   Region Match |   City Match |   Phone Match |   Category Match |
# |----------+-----------------+-----------------+----------------+--------------+---------------+------------------|
# | Accuracy |             100 |           98.84 |          96.91 |        90.83 |         90.41 |            54.62 |

# %% [markdown]
# Looks much better. Still, the accuracy in the category column is pretty low. Now I will start eliminating rows so that the accuracy gets to 100% in the columns.

# %%
df = ds_fb_ggl.drop(ds_fb_ggl[ds_fb_ggl['fb_country_name'] != ds_fb_ggl['ggl_country_name']].index)
print((df['fb_country_name'] == df['ggl_country_name']).value_counts())
df = df.drop(df[df['fb_region_name'] != df['ggl_region_name']].index)
print((df['fb_region_name'] == df['ggl_region_name']).value_counts())
df = df.drop(df[df['fb_city'] != df['ggl_city']].index)
print((df['fb_city'] == df['ggl_city']).value_counts())
df = df.drop(df[df['fb_phone'] != df['ggl_phone']].index)
print((df['fb_phone'] == df['ggl_phone']).value_counts())
df = df.reset_index()
ds_fb_ggl = df
# Out:
# True    42352
# dtype: int64
# True    41504
# dtype: int64
# True    38844
# dtype: int64
# True    36000
# dtype: int64

# %%
ds_fb_ggl['company_match'] = (ds_fb_ggl['ggl_name'] == ds_fb_ggl['fb_name'])

ds_fb_ggl['country_match'] = (ds_fb_ggl['fb_country_name'] == ds_fb_ggl['ggl_country_name'])

ds_fb_ggl['region_match'] =(ds_fb_ggl['fb_region_name'] == ds_fb_ggl['ggl_region_name'])

ds_fb_ggl['phone_match'] = (ds_fb_ggl['fb_phone'] == ds_fb_ggl['ggl_phone'])

ds_fb_ggl['city_match'] = (ds_fb_ggl['fb_city'] == ds_fb_ggl['ggl_city'])

true = 0
for i in range(ds_fb_ggl.shape[0]):
    row = ds_fb_ggl.iloc[i]
    for item in row['fb_categories']:
        if row['ggl_category'] == item:
            true += 1

        
data = [['Accuracy', (ds_fb_ggl['company_match'].value_counts()/ds_fb_ggl.shape[0]*100).iloc[0], 
         (np.round(ds_fb_ggl['country_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0],
         (np.round(ds_fb_ggl['region_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0], 
         (np.round(ds_fb_ggl['city_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0], 
         (np.round(ds_fb_ggl['phone_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0], 
          np.round(true/ds_fb_ggl.shape[0]*100,2)]]
table = tabulate(data, headers=['','Company Match', 'Country Match', 'Region Match', 'City Match', 'Phone Match', 'Category Match'], tablefmt='orgtbl')
print(table)
# Out:
# |          |   Company Match |   Country Match |   Region Match |   City Match |   Phone Match |   Category Match |
# |----------+-----------------+-----------------+----------------+--------------+---------------+------------------|
# | Accuracy |             100 |             100 |            100 |          100 |           100 |            55.04 |

# %%
ds_fb_ggl.to_csv('facebook_google_dataset.csv')

# %%
df = ds_fb_ggl
a =[]
for i in range(df.shape[0]):
    row = df.iloc[i]
    c = 0
    for item in row['fb_categories']:
        if row['ggl_category'] == item: 
            c += 1
    if c==0: 
        a.append(i)

# %%
print(len(a))
df = df.drop(a)
df = df.reset_index()
print(df.shape)
# Out:
# 17799
# (18201, 38)

# %% [markdown]
# **Final results for the Facebook - Google dataset:**

# %%
ds_fb_ggl = df
ds_fb_ggl['company_match'] = (ds_fb_ggl['ggl_name'] == ds_fb_ggl['fb_name'])

ds_fb_ggl['country_match'] = (ds_fb_ggl['fb_country_name'] == ds_fb_ggl['ggl_country_name'])

ds_fb_ggl['region_match'] =(ds_fb_ggl['fb_region_name'] == ds_fb_ggl['ggl_region_name'])

ds_fb_ggl['phone_match'] = (ds_fb_ggl['fb_phone'] == ds_fb_ggl['ggl_phone'])

ds_fb_ggl['city_match'] = (ds_fb_ggl['fb_city'] == ds_fb_ggl['ggl_city'])

true = 0
for i in range(ds_fb_ggl.shape[0]):
    item1 = ds_fb_ggl.iloc[i].at['fb_categories']
    item2 = ds_fb_ggl.iloc[i].at['ggl_category']
    if [value for value in item1 if value in item2]: true += 1
        
data = [['Accuracy', (ds_fb_ggl['company_match'].value_counts()/ds_fb_ggl.shape[0]*100).iloc[0], 
         (np.round(ds_fb_ggl['country_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0],
         (np.round(ds_fb_ggl['region_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0], 
         (np.round(ds_fb_ggl['city_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0], 
         (np.round(ds_fb_ggl['phone_match'].value_counts()/ds_fb_ggl.shape[0]*100,2)).iloc[0], 
          np.round(true/ds_fb_ggl.shape[0]*100,2)]]
table = tabulate(data, headers=['','Company Match', 'Country Match', 'Region Match', 'City Match', 'Phone Match', 'Category Match'], tablefmt='orgtbl')
print(table)
# Out:
# |          |   Company Match |   Country Match |   Region Match |   City Match |   Phone Match |   Category Match |
# |----------+-----------------+-----------------+----------------+--------------+---------------+------------------|
# | Accuracy |             100 |             100 |            100 |          100 |           100 |              100 |

# %% [markdown]
# This is the largest accurate dataset I could get, with ~18000 companies. I will merge this dataset with the website one.

# %%
del ds_fb_ggl['level_0']
del ds_fb_ggl['index']
ds_fb_ggl.head(15)
# Out:
#                         fb_domain  \
# 0              euro-hygiene-34.fr
# 1         lakesidehomeservices.ca
# 2               rossiterboats.com
# 3            caa-architecture.com
# 4                   apexsurety.ca
# 5                 dovercheese.com
# 6              alphascientific.ca
# 7                brokenspirits.ca
# 8                    marilees.com
# 9           albertashrinkwrap.com
# 10  stillwaterchristianschool.org
# 11       pawlovichchiropractic.ca
# 12             parksiderentals.ca
# 13                playcaresrc.com
# 14          rubberduckyresort.com
#
#                                            fb_address  \
# 0   134 rue entrepreneurs, za du vigné, 30420, cal...
# 1
# 2
# 3   601 cordova st w # 270, v6b 1g1, vancouver, bc...
# 4   unit 3 - 4 donald street, r3l 2t7, winnipeg, m...
# 5   307 main street, n0a 1n0, port dover, on, cana...
# 6   8623 granville street unit 143, v6p 5a2, vanco...
# 7   #4 – 3320 14 avenue ne, t2a 6j4, calgary, ab, ...
# 8   170 hwy 20 w unit 5, l0s1e0, fonthill, on, can...
# 9          rr1, t0c 0j0, bentley, ab, canada, alberta
# 10      255 ffa dr, 59901, kalispell, mt, us, montana
# 11
# 12  birds hill park hwy 206, r0e 0k0, winnipeg, mb...
# 13    215 s apopka ave, 34452, inverness, fl, florida
# 14  1069 road 76.5, r0c 3e0, warren, mb, canada, m...
#
#                                         fb_categories     fb_city  \
# 0            [Pest Services & Agricultural Chemicals]   calvisson
# 1   [Appliance Repair & Maintenance, Home Builders...
# 2      [Boats & Yachts Dealers, Boat Tours & Cruises]    markdale
# 3   [Architects & Architectural Services, Other En...   vancouver
# 4           [Insurance -  Agents, Carriers & Brokers]    winnipeg
# 5                   [Dairy Products - Farms & Stores]  port dover
# 6                      [Medical Supply Manufacturers]   vancouver
# 7                    [Distilleries & Malt Processing]     calgary
# 8                   [Bridal Shops & Wedding Supplies]    fonthill
# 9                             [Construction Services]
# 10                                                 []   kalispell
# 11  [Alternative Therapy, Chiropractors, Dentists ...   saskatoon
# 12  [Boat Rental & Chartering Services, Boat Tours...    winnipeg
# 13  [Daycare Centers, Daycare Centers, Preschools ...   inverness
# 14                   [RV Parks & Campgrounds, Hotels]      warren
#
#    fb_country_code fb_country_name  \
# 0               fr          france
# 1               ca
# 2                           canada
# 3               ca          canada
# 4               ca          canada
# 5               ca          canada
# 6               ca          canada
# 7               ca          canada
# 8               ca          canada
# 9               ca
# 10              us   united states
# 11              ca          canada
# 12              ca          canada
# 13              us   united states
# 14                          canada
#
#                                        fb_description  \
# 0
# 1
# 2   At Rossiter Boats we build semi-custom power b...
# 3
# 4
# 5   The Dover Cheese Shop is a food lover’s paradi...
# 6   www.alphascientific.ca Alpha Scientific Repair...
# 7
# 8   Marilee's Bridal - Niagara's favourite boutiqu...
# 9
# 10
# 11
# 12  All rentals come with a trailer so you can go ...
# 13
# 14  Family Campground located approx 20 mins from ...
#
#                       fb_email                                fb_link  \
# 0                                          https://euro-hygiene-34.fr
# 1                                     https://lakesidehomeservices.ca
# 2       info@rossiterboats.com               http://rossiterboats.com
# 3   office@caa-arcitecture.com            http://caa-architecture.com
# 4                                               https://apexsurety.ca
# 5         info@dovercheese.com                 http://dovercheese.com
# 6     sales@alphascientific.ca              http://alphascientific.ca
# 7                                            https://brokenspirits.ca
# 8            info@marilees.com                    http://marilees.com
# 9                                       https://albertashrinkwrap.com
# 10                              https://stillwaterchristianschool.org
# 11                                   https://pawlovichchiropractic.ca
# 12                                          http://parksiderentals.ca
# 13                                            https://playcaresrc.com
# 14  info@rubberduckyresort.com           http://rubberduckyresort.com
#
#                                fb_name  ... ggl_region_code   ggl_region_name  \
# 0                         euro hygiène  ...             occ         occitanie
# 1               lakeside home services  ...
# 2                       rossiter boats  ...              on           ontario
# 3     chandler associates architecture  ...              bc  british columbia
# 4              apex surety & insurance  ...              mb          manitoba
# 5                the dover cheese shop  ...              on           ontario
# 6     alpha scientific repair services  ...              bc  british columbia
# 7            broken spirits distillery  ...              ab           alberta
# 8                     marilee's bridal  ...              on           ontario
# 9                  alberta shrink wrap  ...
# 10         stillwater christian school  ...              mt           montana
# 11              pawlovich chiropractic  ...              sk      saskatchewan
# 12                    parkside rentals  ...                          manitoba
# 13    playcare school readiness center  ...              fl           florida
# 14  rubber ducky resort and campground  ...              on           ontario
#
#                                              ggl_text ggl_zip_code  \
# 0   4.7 (3) · Pest control service 3+ years in bus...
# 1   5.0 (2) · Appliance repair service Closed ⋅ Op...
# 2   4.5 (4) · Boat builders Markdale, ON, Canada O...
# 3   4.5 (2) · Architect 5+ years in business · Van...      v6c 2g8
# 4   No reviews · Insurance broker 4 Donald St #3 O...      r3l 2t7
# 5   Cheese shop Port Dover, ON, Canada · +1 519-71...      n0a 1n0
# 6   No reviews · Medical equipment supplier Vancou...      v6p 5a3
# 7   5.0 (8) · Distillery 3320 14 Ave NE Unit 4 Clo...      t2a 6j4
# 8   4.5 (73) · Bridal shop 5+ years in business · ...      l0s 1e5
# 9   5.0 (1) · Construction company Bentley, AB, Ca...
# 10  4.7 (3) · Private educational institution Kali...        59901
# 11  4.8 (25) · Chiropractor 120-3010 Preston Ave S...      s7t 0v2
# 12  4.3 (8) · Boat rental service Springfield, MB,...
# 13  4.4 (14) · Preschool Inverness, FL Closed ⋅ Op...        34452
# 14  4.3 (224) Modest kitchenette rooms at resort f...
#
#                        ggl_domain company_match country_match region_match  \
# 0              euro-hygiene-34.fr          True          True         True
# 1         lakesidehomeservices.ca          True          True         True
# 2               rossiterboats.com          True          True         True
# 3            caa-architecture.com          True          True         True
# 4                   apexsurety.ca          True          True         True
# 5                 dovercheese.com          True          True         True
# 6              alphascientific.ca          True          True         True
# 7                brokenspirits.ca          True          True         True
# 8                    marilees.com          True          True         True
# 9           albertashrinkwrap.com          True          True         True
# 10  stillwaterchristianschool.org          True          True         True
# 11       pawlovichchiropractic.ca          True          True         True
# 12             parksiderentals.ca          True          True         True
# 13                playcaresrc.com          True          True         True
# 14          rubberduckyresort.com          True          True         True
#
#    phone_match city_match
# 0         True       True
# 1         True       True
# 2         True       True
# 3         True       True
# 4         True       True
# 5         True       True
# 6         True       True
# 7         True       True
# 8         True       True
# 9         True       True
# 10        True       True
# 11        True       True
# 12        True       True
# 13        True       True
# 14        True       True
#
# [15 rows x 36 columns]

# %% [markdown]
# **<font size="4"> MERGING ALL THE THREE DATASETS (AGAIN) </font>**

# %%
ds_all = ds_fb_ggl.merge(web_ds, left_on='ggl_name', right_on='web_legal_name')
ds_all.head()
# Out:
#                  fb_domain                                         fb_address  \
# 0  lakesidehomeservices.ca
# 1     caa-architecture.com  601 cordova st w # 270, v6b 1g1, vancouver, bc...
# 2            apexsurety.ca  unit 3 - 4 donald street, r3l 2t7, winnipeg, m...
# 3       alphascientific.ca  8623 granville street unit 143, v6p 5a2, vanco...
# 4       parksiderentals.ca  birds hill park hwy 206, r0e 0k0, winnipeg, mb...
#
#                                        fb_categories    fb_city  \
# 0  [Appliance Repair & Maintenance, Home Builders...
# 1  [Architects & Architectural Services, Other En...  vancouver
# 2          [Insurance -  Agents, Carriers & Brokers]   winnipeg
# 3                     [Medical Supply Manufacturers]  vancouver
# 4  [Boat Rental & Chartering Services, Boat Tours...   winnipeg
#
#   fb_country_code fb_country_name  \
# 0              ca
# 1              ca          canada
# 2              ca          canada
# 3              ca          canada
# 4              ca          canada
#
#                                       fb_description  \
# 0
# 1
# 2
# 3  www.alphascientific.ca Alpha Scientific Repair...
# 4  All rentals come with a trailer so you can go ...
#
#                      fb_email                          fb_link  \
# 0                              https://lakesidehomeservices.ca
# 1  office@caa-arcitecture.com      http://caa-architecture.com
# 2                                        https://apexsurety.ca
# 3    sales@alphascientific.ca        http://alphascientific.ca
# 4                                    http://parksiderentals.ca
#
#                             fb_name  ... web_domain_suffix web_language  \
# 0            lakeside home services  ...                ca           en
# 1  chandler associates architecture  ...               com           en
# 2           apex surety & insurance  ...                ca           en
# 3  alpha scientific repair services  ...                ca           en
# 4                  parkside rentals  ...                ca           en
#
#                      web_legal_name web_main_city web_main_country  \
# 0            lakeside home services   stittsville           canada
# 1  chandler associates architecture     vancouver           canada
# 2           apex surety & insurance      winnipeg           canada
# 3  alpha scientific repair services     vancouver           canada
# 4                  parkside rentals        dugald           canada
#
#     web_main_region    web_phone           web_site_name web_tld  \
# 0           ontario  16138318840  Lakeside Home Services      ca
# 1  british columbia  16046873325                Chandler     com
# 2          manitoba  12045602508           INSURANCEAPEX      ca
# 3  british columbia  16046903380        Alpha Scientific      ca
# 4          manitoba  12042325434        Parkside Rentals      ca
#
#                           web_category
# 0       Appliance Repair & Maintenance
# 1  Architects & Architectural Services
# 2           Liability Insurance Agency
# 3         Medical Supply Manufacturers
# 4    Boat Rental & Chartering Services
#
# [5 rows x 47 columns]

# %%
# ds = ds_all
ds_all['company_match'] = ((ds_all['web_legal_name'] == ds_all['ggl_name'])&(ds_all['ggl_name'] == ds_all['fb_name']))

ds_all['country_match'] = ((ds_all['web_main_country'] == ds_all['fb_country_name'])&(ds_all['fb_country_name'] == ds_all['ggl_country_name']))

ds_all['region_match'] = ((ds_all['web_main_region'] == ds_all['fb_region_name'])&(ds_all['fb_region_name'] == ds_all['ggl_region_name']))

ds_all['phone_match'] = ((ds_all['web_phone'] == ds_all['fb_phone'])&(ds_all['fb_phone'] == ds_all['ggl_phone']))

ds_all['city_match'] = ((ds_all['web_main_city'] == ds_all['fb_city']) & (ds_all['fb_city'] == ds_all['ggl_city']))

true = 0
for i in range(ds_all.shape[0]):
    row = ds_all.iloc[i]
    for item in row['fb_categories']:
        if row['ggl_category'] == item and row['web_category'] == item:
            true += 1

data = [['Accuracy', (ds_all['company_match'].value_counts()/ds_all.shape[0]*100).iloc[0], (np.round(ds_all['country_match'].value_counts()/ds_all.shape[0]*100,2)).iloc[0],
     (np.round(ds_all['region_match'].value_counts()/ds_all.shape[0]*100,2)).iloc[0], (np.round(ds_all['city_match'].value_counts()/ds_all.shape[0]*100,2)).iloc[0],
         (np.round(ds_all['phone_match'].value_counts()/ds_all.shape[0]*100,2)).iloc[0], np.round(true/ds_all.shape[0]*100,2)]]
table = tabulate(data, headers=['','Company Match', 'Country Match', 'Region Match', 'City Match', 'Phone Match', 'Category Match'], tablefmt='orgtbl')
print(table)
# Out:
# |          |   Company Match |   Country Match |   Region Match |   City Match |   Phone Match |   Category Match |
# |----------+-----------------+-----------------+----------------+--------------+---------------+------------------|
# | Accuracy |             100 |           80.62 |           78.2 |        66.84 |         75.84 |            54.86 |

# %% [markdown]
# This is better than the first dataset. I will now perform the same steps in order to get a better accuracy.

# %%
def fill_missing_values(fb_column, web_column):
#     ds_all[fb_column] = ds_all[fb_column].replace('',np.nan, regex=True)
#     ds_all[fb_column].fillna(ds_all[web_column], inplace=True)
    ds_all[web_column] = ds_all[web_column].replace('',np.nan, regex=True)
    ds_all[web_column].fillna(ds_all[fb_column], inplace=True)

fill_missing_values('fb_country_name', 'web_main_country')
fill_missing_values('fb_region_name', 'web_main_region')
fill_missing_values('fb_city', 'web_main_city')
fill_missing_values('fb_phone', 'web_phone')

# %%
df = ds_all
df = df.drop(df[df['fb_country_name'] != df['web_main_country']].index)
print((df['fb_country_name'] == df['web_main_country']).value_counts())
df = df.drop(df[df['fb_region_name'] != df['web_main_region']].index)
print((df['fb_region_name'] == df['web_main_region']).value_counts())
df = df.drop(df[df['fb_city'] != df['web_main_city']].index)
print((df['fb_city'] == df['web_main_city']).value_counts())
df = df.drop(df[df['fb_phone'] != df['web_phone']].index)
print((df['fb_phone'] == df['web_phone']).value_counts())
df = df.reset_index()
# Out:
# True    4527
# dtype: int64
# True    4362
# dtype: int64
# True    3762
# dtype: int64
# True    3114
# dtype: int64

# %%
ds_all = df
a =[]
for i in range(ds_all.shape[0]):
    row = ds_all.iloc[i]
    c = 0
    for item in row['fb_categories']:
        if row['ggl_category'] == item and row['web_category'] == item: 
            c += 1
    if c==0: 
        a.append(i)
ds_all = ds_all.drop(a)
ds_all = ds_all.reset_index()

# %%
# ds = ds_all
ds_all['company_match'] = ((ds_all['web_legal_name'] == ds_all['ggl_name']) & (ds_all['ggl_name'] == ds_all['fb_name']))

ds_all['country_match'] = ((ds_all['web_main_country'] == ds_all['fb_country_name'])&(ds_all['fb_country_name'] == ds_all['ggl_country_name']))

ds_all['region_match'] = ((ds_all['web_main_region'] == ds_all['fb_region_name'])&(ds_all['fb_region_name'] == ds_all['ggl_region_name']))

ds_all['phone_match'] = ((ds_all['web_phone'] == ds_all['fb_phone'])&(ds_all['fb_phone'] == ds_all['ggl_phone']))

ds_all['city_match'] = ((ds_all['web_main_city'] == ds_all['fb_city']) & (ds_all['fb_city'] == ds_all['ggl_city']))

true = 0
for i in range(ds_all.shape[0]):
    item1 = ds_all.iloc[i].at['fb_categories']
    item2 = ds_all.iloc[i].at['ggl_category']
    item3 = ds_all.iloc[i].at['web_category']
    c =  [value for value in item1 if value in item2]
    if [value for value in c if value in item3]: true += 1

data = [['Accuracy', (ds_all['company_match'].value_counts()/ds_all.shape[0]*100).iloc[0], (np.round(ds_all['country_match'].value_counts()/ds_all.shape[0]*100,2)).iloc[0],
     (np.round(ds_all['region_match'].value_counts()/ds_all.shape[0]*100,2)).iloc[0], (np.round(ds_all['city_match'].value_counts()/ds_all.shape[0]*100,2)).iloc[0],
         (np.round(ds_all['phone_match'].value_counts()/ds_all.shape[0]*100,2)).iloc[0], np.round(true/ds_all.shape[0]*100,2)]]
table = tabulate(data, headers=['','Company Match', 'Country Match', 'Region Match', 'City Match', 'Phone Match', 'Category Match'], tablefmt='orgtbl')
print(table)
# Out:
# |          |   Company Match |   Country Match |   Region Match |   City Match |   Phone Match |   Category Match |
# |----------+-----------------+-----------------+----------------+--------------+---------------+------------------|
# | Accuracy |             100 |             100 |            100 |          100 |           100 |              100 |

# %%
del ds_all['level_0']
del ds_all['index']

# %%
ds_all.to_csv('complete_dataset.csv')

# %%
print(ds_all.shape)
# Out:
# (1610, 47)

# %% [markdown]
# So I merged all the three datasets available and got around 1600 companies. This is the complete dataset which features all the 3 datasets merged.
